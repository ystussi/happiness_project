# %% [markdown]
# Use the read_excel function of the pandas package to read the data into a dataframe wh_all_df

# %%
import pandas as pd

# %%
#pd.read_excel?
wh_all_df = pd.read_excel('WHR21.xls')

# %%
wh_all_df
# Out:
#         Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0          Australia  2005     7.340688           10.570512        0.967892
# 1            Belgium  2005     7.262290           10.591697        0.934875
# 2             Brazil  2005     6.636771            9.421541        0.882923
# 3             Canada  2005     7.418048           10.609852        0.961552
# 4     Czech Republic  2005     6.439257           10.157401        0.918759
# ...              ...   ...          ...                 ...             ...
# 1992       Venezuela  2020     4.892200            9.073104        0.860927
# 1993         Vietnam  2020     5.410800            8.973157        0.849987
# 1994           Yemen  2020     3.657900            7.578437        0.831537
# 1995          Zambia  2020     4.073400            8.145451        0.707518
# 1996        Zimbabwe  2020     3.144800            7.942595        0.750470
#
# ...

# %%
wh_all_df.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect',
#        'Confidence in national government', 'Democratic Quality',
#        'Delivery Quality', 'Standard deviation of ladder by country-year',
#        'Standard deviation/Mean of ladder by country-year',
#        'GINI index (World Bank estimate)',
#        'GINI index (World Bank estimate), average 2000-2017, unbalanced panel',
#        'gini of household income reported in Gallup, by wp5-year',
#        'Most people can be trusted, Gallup',
#        'Most people can be trusted, WVS round 1981-1984',
#        'Most people can be trusted, WVS round 1989-1993',
#        'Most people can be trusted, WVS round 1994-1998',
#        'Most people can be trusted, WVS round 1999-2004',
# ...

# %%
cols_of_interest = wh_all_df.columns[1:9]

# %%
wh_withna_df = wh_all_df[cols_of_interest]

# %%
wh_withna_df
# Out:
#       year  Life Ladder  Log GDP per capita  Social support  \
# 0     2005     7.340688           10.570512        0.967892
# 1     2005     7.262290           10.591697        0.934875
# 2     2005     6.636771            9.421541        0.882923
# 3     2005     7.418048           10.609852        0.961552
# 4     2005     6.439257           10.157401        0.918759
# ...    ...          ...                 ...             ...
# 1992  2020     4.892200            9.073104        0.860927
# 1993  2020     5.410800            8.973157        0.849987
# 1994  2020     3.657900            7.578437        0.831537
# 1995  2020     4.073400            8.145451        0.707518
# 1996  2020     3.144800            7.942595        0.750470
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 0                            71.400002                      0.934973
# 1                            69.900002                      0.923843
# ...

# %%
xxx = wh_all_df[]

# %%
import seaborn as sns

# %%
sns.pairplot(wh_withna_df)

# %%
wh_withna_df.isna().sum()
# Out:
# year                                  0
# Life Ladder                           0
# Log GDP per capita                   29
# Social support                       13
# Healthy life expectancy at birth     52
# Freedom to make life choices         31
# Generosity                           83
# Perceptions of corruption           103
# dtype: int64

# %%
wh_df = wh_withna_df['Log GDP per capita'].fillna(wh_withna_df['Log GDP per capita'].median())
wh_df = wh_df['Social support'].fillna(wh_)

# %%
wh_df = wh_withna_df.copy()

# %%
wh_df['Log GDP per capita'] = wh_withna_df['Log GDP per capita'].fillna(wh_withna_df['Log GDP per capita'].median())
wh_df['Social support'] = wh_withna_df['Social support'].fillna(wh_withna_df['Social support'].median())
wh_df['Healthy life expectancy at birth'] = wh_withna_df['Healthy life expectancy at birth'].fillna(wh_withna_df['Healthy life expectancy at birth'].median())
wh_df['Freedom to make life choices'] = wh_withna_df['Freedom to make life choices'].fillna(wh_withna_df['Freedom to make life choices'].median())
wh_df['Generosity'] = wh_withna_df['Generosity'].fillna(wh_withna_df['Generosity'].median())
wh_df['Perceptions of corruption'] = wh_withna_df['Perceptions of corruption'].fillna(wh_withna_df['Perceptions of corruption'].median())

# %%
wh_df.isna().sum()
# Out:
# year                                0
# Life Ladder                         0
# Log GDP per capita                  0
# Social support                      0
# Healthy life expectancy at birth    0
# Freedom to make life choices        0
# Generosity                          0
# Perceptions of corruption           0
# dtype: int64

# %%
wh_df.corr()
# Out:
#                                       year  Life Ladder  Log GDP per capita  \
# year                              1.000000     0.014175            0.061659
# Life Ladder                       0.014175     1.000000            0.774293
# Log GDP per capita                0.061659     0.774293            1.000000
# Social support                   -0.025135     0.705897            0.679580
# Healthy life expectancy at birth  0.143045     0.739771            0.821827
# Freedom to make life choices      0.209633     0.524792            0.363468
# Generosity                       -0.045051     0.175126           -0.018821
# Perceptions of corruption        -0.073930    -0.412272           -0.322879
#
#                                   Social support  \
# year                                   -0.025135
# Life Ladder                             0.705897
# Log GDP per capita                      0.679580
# Social support                          1.000000
# ...

# %%
sns.heatmap(wh_df.corr())
# Out:
# <AxesSubplot:>

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [autoreload of happypred failed: Traceback (most recent call last):
#   File "/home/brainhacker/.conda/envs/happy38/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/brainhacker/.conda/envs/happy38/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/brainhacker/.conda/envs/happy38/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/home/brainhacker/.conda/envs/happy38/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
# ...

# %%
from happypred import whdata_to_csv

# %%
whdata_to_csv('WHR21.xls')
# Out:
# ('X_train.csv', 'y_train.csv', 'X_test.csv', 'y_test.csv')
